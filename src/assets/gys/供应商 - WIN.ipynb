# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import matplotlib.font_manager as fm
# %matplotlib inline
#plt.rcParams['font.family'] = ['Arial Unicode MS']
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
data = pd.read_excel("供应商.xlsx")

datadf = pd.DataFrame(data.iloc[:, 0:])
datadf
# Out:
#     Unnamed: 0 Unnamed: 1  Unnamed: 2 Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0          NaN        NaN         NaN      stkcd         NaN  前五名供应商占采购比
# 1          NaN        黑芝麻         NaN     000716         NaN      0.3445
# 2          NaN       云南能投         NaN     002053         NaN      0.2836
# 3          NaN       三全食品         NaN     002216         NaN      0.2108
# 4          NaN       皇氏集团         NaN     002329         NaN      0.2979
# 5          NaN       双塔食品         NaN     002481         NaN      0.6791
# 6          NaN       佳隆股份         NaN     002495         NaN      0.4289
# 7          NaN       涪陵榨菜         NaN     002507         NaN      0.2165
# 8          NaN        贝因美         NaN     002570         NaN      0.3838
# 9          NaN        金达威         NaN     002626         NaN      0.1703
# 10         NaN       加加食品         NaN     002650         NaN      0.3693
# 11         NaN       克明面业         NaN     002661         NaN       0.331
# ...

# %%
#for i in range(datadf.shape[0])
for i in range(0,43):
    newdata = datadf.iloc[i, 5:7]
    ax=newdata.plot(kind='pie', labels=["前五名占供应商采占比", "其他供应商采购占比"], autopct='%1.1f%%')
        #plt.rcParams['font.family'] = ['SimHei']
    ax.set_ylabel("")
    fig=ax.get_figure()
    plt.rcParams['savefig.dpi'] = 200
    #plt.rcParams['figure.figsize'] = (5.0, 4.0)
    fig.savefig(r'C:\Users\Administrator\Desktop\项目素材\供应商\%s.jpg'%datadf.iloc[i,1])
    plt.close('all')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5956dd0c6101> in <module>
#       2 for i in range(0,43):
#       3     newdata = datadf.iloc[i, 5:7]
# ----> 4     ax=newdata.plot(kind='pie',  autopct='%1.1f%%')
#       5         #plt.rcParams['font.family'] = ['SimHei']
#       6     ax.set_ylabel("")
#
# D:\Anaconda\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ...
