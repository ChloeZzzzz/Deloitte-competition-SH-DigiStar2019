# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import matplotlib.font_manager as fm
# %matplotlib inline
plt.rcParams['font.family'] = ['Arial Unicode MS']
#plt.rcParams['font.sans-serif']=['SimHei']
#plt.rcParams['axes.unicode_minus']=False

# %%
data = pd.read_excel("投诉数据final.xlsx")
data = data.rename(columns=data.loc[0])
data = data.iloc[1:,:]
data2 = pd.DataFrame(pd.read_excel("食品上市公司名单2.xlsx"))
data2 = data2.rename(columns=data2.iloc[0,:])
data2 = data2.iloc[1:, 9:]
data = pd.merge(data, data2, on="市公司简称")
data
# Out:
#      市公司代码 市公司简称    1月    2月    3月    4月    5月    6月  min   max       score  \
# 0   000716   黑芝麻   838   829  1311  1104   545   688  103  1495    0.579741
# 1   002053  云南能投   560   924   830   114   877   496  103  1495    0.717672
# 2   002216  三全食品   427   970   810  1384   288   217  103  1495    0.918103
# 3   002329  皇氏集团  1001   856  1404   999   130  1354  103  1495    0.101293
# 4   002481  双塔食品   517   232   763  1060  1378   792  103  1495    0.505029
# 5   002495  佳隆股份   607   729  1457   465   557   193  103  1495    0.935345
# 6   002507  涪陵榨菜  1140   827   676  1176   688  1495  103  1495           0
# 7   002570   贝因美   183  1192   642  1239   627   748  103  1495    0.536638
# 8   002626   金达威   475   810  1409  1091  1303   145  103  1495    0.969828
# 9   002650  加加食品  1171  1489   455  1218  1269   574  103  1495    0.661638
# 10  002661  克明面业  1448   629  1298   401  1201  1357  103  1495   0.0991379
# 11  002719   麦趣尔  1445  1463   639   845   712   950  103  1495    0.391523
# 12  002732  燕塘乳业  1038  1132   807  1465  1277   387  103  1495    0.795977
# 13  002770  科迪乳业  1387   984   688  1279   854   448  103  1495    0.752155
# 14  002820   桂发祥   910   341   781   348   918  1014  103  1495    0.345546
# 15  002847  盐津铺子  1223  1324   552   561   447   312  103  1495    0.849856
# 16  002910  庄园牧场   426   439   513   579  1106   103  103  1495           1
# 17  300146  汤臣倍健   763   369  1081   112   260   130  103  1495    0.980603
# 18  300149  量子生物  1244   466   930  1483  1285  1058  103  1495    0.313937
# 19  300381   溢多利   727   909   604  1492  1061   709  103  1495    0.564655
# 20  300401  花园生物   409  1390   342   740   952   185  103  1495    0.941092
# 21  600073  上海梅林   839  1216   362  1044   756  1087  103  1495    0.293103
# 22  600186  莲花健康   313   703   825   941   626   555  103  1495    0.675287
# 23  600298  安琪酵母   885  1452   437   450   241   752  103  1495    0.533764
# 24  600305  恒顺醋业   595   673   587  1119   110   640  103  1495    0.614224
# 25  600381  青海春天   325   450  1108   254   103  1191  103  1495    0.218391
# 26  600419  天润乳业  1317  1197   434   134   352   853  103  1495    0.461207
# 27  600429  三元股份  1136   657  1280   677   497   920  103  1495    0.413075
# 28  600597  光明乳业   776   932   948   391   342   962  103  1495    0.382902
# 29  600866  星湖科技   173  1075   273  1262  1198   274  103  1495    0.877155
# 30  600872  中炬高新   956   482  1439   960   473  1424  103  1495   0.0510057
# 31  600873  梅花生物   106  1188   742   646  1133  1447  103  1495   0.0344828
# 32  600882  广泽股份   507   297  1118  1318  1009   568  103  1495    0.665948
# 33  600887  伊利股份  1366  1101  1393   742  1227   892  103  1495     0.43319
# 34  600929  湖南盐业   684   561   191   477   497   899  103  1495    0.428161
# 35  603020  爱普股份   162   407   478  1244  1122  1222  103  1495    0.196121
# 36  603027  千禾味业   397   393   551  1427   287   635  103  1495    0.617816
# 37  603043  广州酒家  1360  1140   415   132  1003   887  103  1495    0.436782
# 38  603079  圣达生物   452   351  1088   606   773  1401  103  1495   0.0675287
# 39  603288  海天味业  1465   107  1298   527   174   209  103  1495    0.923851
# 40  603696  安记食品  1427  1141  1214   877   535   243  103  1495    0.899425
# 41  603866  桃李面包   749   627   562  1438   121   434  103  1495    0.762213
# 42  603885  元祖股份  1109  1036   772   827   629  1483  103  1495  0.00862069
#
#     拼音简写
# 0    hzm
# 1   ynnt
# 2   qusp
# 3   hsjt
# 4   stsp
# 5   jlgf
# 6   flzc
# 7    bym
# 8    jdw
# 9   jjsp
# 10  kmmy
# 11   mqe
# 12  ytry
# 13  kdry
# 14   gfx
# 15  yjpz
# 16  zymc
# 17  tcbj
# 18  lzsw
# 19   ydl
# 20  hysw
# 21  shml
# 22  lhjk
# 23  aqjm
# 24  hscy
# 25  qhct
# 26  trry
# 27  sygf
# 28  gmry
# 29  xhkj
# 30  zjgx
# 31  mhsw
# 32  gzgf
# 33  ylgf
# 34  hnyy
# 35  apgf
# 36  qhwy
# 37  gzjj
# 38  sdsw
# 39  htwy
# 40  ajsp
# 41  tlmb
# 42  yzgf

# %%
#for i in range(1, data.shape[0]):
for i in range(0,42):
    newdata = pd.DataFrame(data.iloc[i, 2:8])
    index = [""]
    for j in newdata.index:
        index.append(j)

    #font = fm.FontProperties(fname='/System/Library/Fonts/STHeiti Light.ttc')  # speicify font
    ax = newdata.plot(kind='line', style='.-')
    ax.set_xticklabels(labels=index)
    ax.legend("")
    ax.set_ylim(bottom=0, top=1500)
    ax.set_title("消费者投诉趋势图")
    plt.rcParams['savefig.dpi'] = 200
    fig=ax.get_figure()
    fig.savefig(r'/Users/wangning/Desktop/项目素材/xfzts/%s.jpg'%data.iloc[i,11])
