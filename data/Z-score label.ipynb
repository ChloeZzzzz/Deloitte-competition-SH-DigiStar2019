# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import matplotlib.font_manager as fm

# %%
data = pd.read_excel("z-score label2.xlsx")
data = data.rename(columns={"Unnamed: 0": "公司名"})
 
datadf = []
for i in range(0, data.shape[0], 2):
    datadf.append(data.iloc[i,:])
    
datadf = pd.DataFrame(datadf)
datadf
# Out:
#       公司名  2017-09-30  2017-12-31  2018-03-31  2018-06-30  2018-09-30  \
# 0     黑芝麻    2.238104    1.725533    1.167987    0.965327    1.108556
# 2    云南能投    1.015999    3.077950    2.439944    0.607786    1.827478
# 4    三全食品    3.258406    2.811491    2.272741    2.957576    2.824219
# 6    皇氏集团    1.669963    1.569360    1.167387    1.314350    1.292691
# 8    双塔食品    3.109187    2.847603    2.117631    2.399353    2.450396
# 10   佳隆股份   23.738474   18.095128   14.686634   14.548017   12.848672
# 12   涪陵榨菜   10.379475   16.322609   19.226582   24.214032   23.961842
# 14  *ST因美    2.335085    1.181139    1.097124    1.190040    1.377757
# 16    金达威    6.525429   10.166554   10.773810    8.368891    4.768663
# 18   加加食品    1.050790    6.168789    4.470308    0.978187    1.197719
# 20   克明面业    4.824455    4.723952    0.928636    3.495500    2.772414
# 22    麦趣尔    3.905337    3.714498    3.571650    4.876481    0.962153
# ...

# %%
#for i in range(0, datadf.shape[0]):

data_select = datadf.iloc[i, 1:].astype(float)
data_select
# Out:
# 2017-09-30    33.211636
# 2017-12-31    42.295778
# 2018-03-31    35.836010
# 2018-06-30    62.551005
# 2018-09-30    34.708851
# 2018-12-31    39.493985
# 2019-03-31    51.826239
# Name: 38, dtype: float64

# %%
font = fm.FontProperties(fname='/System/Library/Fonts/STHeiti Light.ttc')  # speicify font
ax = data_select.plot(kind='line', style='.-')

index = [""]
for j in data_select.index:
    index.append(j)
    
ax.set_xticklabels(labels=index, fontproperties=font)
ax.legend("")
ax.set_title("Z-score", fontproperties=font)

plt.axhline(y=1.23, color='r', linestyle='--')
plt.axhline(y=2.9, color='r', linestyle='--')
plt.show()
