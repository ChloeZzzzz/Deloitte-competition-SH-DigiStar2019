# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
import matplotlib.font_manager as fm

# %%
data = pd.read_excel("供应商.xlsx")

datadf = pd.DataFrame(data.iloc[:, 2:])
datadf
# Out:
#           前五名供应商占采购比  Unnamed: 3
# 黑芝麻  NaN      0.3445      0.6555
# 云南能投 NaN      0.2836      0.7164
# 三全食品 NaN      0.2108      0.7892
# 皇氏集团 NaN      0.2979      0.7021
# 双塔食品 NaN      0.6791      0.3209
# 佳隆股份 NaN      0.4289      0.5711
# 涪陵榨菜 NaN      0.2165      0.7835
# 贝因美  NaN      0.3838      0.6162
# 金达威  NaN      0.1703      0.8297
# 加加食品 NaN      0.3693      0.6307
# 克明面业 NaN      0.3310      0.6690
# 麦趣尔  NaN      0.3892      0.6108
# 燕塘乳业 NaN      0.3134      0.6866
# 科迪乳业 NaN      0.1229      0.8771
# 桂发祥  NaN      0.2674      0.7326
# 盐津铺子 NaN      0.2482      0.7518
# 庄园牧场 NaN      0.3041      0.6959
# 汤臣倍健 NaN      0.3679      0.6321
# 量子生物 NaN      0.4968      0.5032
# 溢多利  NaN      0.2366      0.7634
# 花园生物 NaN      0.4601      0.5399
# 上海梅林 NaN      0.0275      0.9725
# 莲花健康 NaN      0.4946      0.5054
# 安琪酵母 NaN      0.1243      0.8757
# 恒顺醋业 NaN      0.1815      0.8185
# 青海春天 NaN      0.8100      0.1900
# 天润乳业 NaN      0.3040      0.6960
# 三元股份 NaN      0.2855      0.7145
# 光明乳业 NaN      0.1520      0.8480
# 星湖科技 NaN      0.4115      0.5885
# 中炬高新 NaN      0.2193      0.7807
# 梅花生物 NaN      0.0952      0.9048
# 广泽股份 NaN      0.4676      0.5324
# 伊利股份 NaN      0.1700      0.8300
# 湖南盐业 NaN         NaN         NaN
# 爱普股份 NaN         NaN         NaN
# 千禾味业 NaN      0.1946      0.8054
# 广州酒家 NaN      0.1000      0.9000
# 圣达生物 NaN      0.3748      0.6252
# 海天味业 NaN      0.0282      0.9718
# 安记食品 NaN      0.1827      0.8173
# 桃李面包 NaN      0.0786      0.9214
# 元祖股份 NaN      0.1098      0.8902

# %%
#for i in range(datadf.shape[0])
newdata = datadf.iloc[i, :]


plt.pie(newdata, labels=["前五名占供应商采购额", "总采购额"], autopct='%1.1f%%')
plt.rcParams['font.family'] = ['SimHei']
